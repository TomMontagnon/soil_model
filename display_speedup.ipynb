# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
plt.ioff()

# %%
data = np.load("data/speedups/cell_len_values v1.0 2025-02-02 17:24.npz", allow_pickle=True)

git_tag=data["git_tag"].item()
traj_type=data["traj_type"].item()
traj_planned=data["traj_planned"]
param=data["param"].item()
name=data["name"].item()
measures=data["data"].item()

# %%
x = measures.keys()
y = list(map(float,measures.values()))
# Out:
# [2.754, 0.248, 0.238, 0.441, 0.395, 1.74, 1.98, 6.986, 11.402] [3.754, 1.248, 1.238, 1.441, 1.395, 2.74, 2.98, 7.986, 12.402]

# %%
plt.plot(x, y, marker='o', linestyle='-', color='b', label="Évolution") 
plt.plot(x, y2, marker='o', linestyle='-', color='r', label="Évolution")

# %%
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
